# %%
# Exercice 1 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

df = pd.read_csv('train.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.head())
df.describe()
df.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
train_updated = pd.DataFrame(df)

train_updated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(train_updated.head())
train_updated.describe()
train_updated.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
# Remove duplicate rows
train_data = train_updated.drop_duplicates()

# Verify duplicates are removed
print(train_updated.duplicated().sum())
# Out:
# 0

# %%
# train_data = train_updated(['Cabin'], axis=1)

# %%
# import pandas as pd

# df = pd.read_csv('train.csv')

# # df

# # train_updated = df = pd.DataFrame(df)

# # train_updated

# %%
# train_updated = df = pd.DataFrame(df)

# train_updated

# %%
#Exercice 2

# Check for missing values in a DataFrame
train_checked = train_updated.isnull()
print(train_checked.head())
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
# Count missing values in each column
train_checked = train_updated.isnull().sum()
print(train_checked)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Remove rows with missing values
train_cleaned = train_updated.dropna()

# %%
train_cleaned.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Fill missing values with a specific value (e.g., 0)
train_filled = train_updated.fillna(0)
train_filled.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# # Fill missing values with the mean of the column
# train_filled = train_updated.fillna(train_updated.mean())
# train_filled.isnull().sum()

# 2. Remplir les valeurs manquantes PROPERMENT
train_filled = df.fillna({
    'Age': df['Age'].median(),  # Médiane pour l'âge
    'Fare': df['Fare'].mean(),  # Moyenne pour le prix
    'Cabin': 'Unknown',         # Valeur textuelle pour les cabines
    'Embarked': df['Embarked'].mode()[0]  # Mode (valeur la plus fréquente)
})
# Vérification des valeurs manquantes après remplissage
print(train_filled.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# from sklearn.impute import KNNImputer

# imputer = KNNImputer(n_neighbors=2)
# train_imputed = imputer.fit_transform(train_updated)

# %%
from sklearn.impute import KNNImputer
import pandas as pd

# Supposons que votre DataFrame original s'appelle 'df'
# Si vous avez utilisé un autre nom, remplacez 'df' par votre vrai nom de variable

# 1. Sélectionner seulement les colonnes numériques
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df_numeric = df[numeric_cols].copy()

# 2. Initialiser et appliquer KNNImputer
imputer = KNNImputer(n_neighbors=5)
imputed_data = imputer.fit_transform(df_numeric)

# 3. Recréer le DataFrame avec les valeurs imputées
df_imputed = pd.DataFrame(imputed_data, columns=df_numeric.columns)

# 4. Ajouter les colonnes non-numériques (sans imputation KNN)
non_numeric_cols = df.select_dtypes(exclude=['int64', 'float64']).columns
for col in non_numeric_cols:
    df_imputed[col] = df[col]
    
# 5. Imputation simple pour les colonnes catégorielles si nécessaire
for col in non_numeric_cols:
    if df_imputed[col].isnull().any():
        df_imputed[col] = df_imputed[col].fillna('Unknown')  # ou mode() pour les catégories

# Vérification
print(df_imputed.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Name           0
# Sex            0
# Ticket         0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Exercice 3

df['FamilySize'] = df['SibSp'] + df['Parch'] + 1  # +1 pour inclure la personne elle-même

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder

# Chargement des données
df = pd.read_csv('train.csv')

## 1. Création de nouvelles features
# Family Size = SibSp + Parch + 1 (la personne elle-même)
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Extraction du titre depuis le nom (Mr, Mrs, Miss, etc.)
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Simplification des titres moins courants
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 
                                  'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

## 2. Conversion des variables catégorielles
# Label Encoding pour le sexe
label_encoder = LabelEncoder()
df['Sex_encoded'] = label_encoder.fit_transform(df['Sex'])

# One-Hot Encoding pour les titres
title_dummies = pd.get_dummies(df['Title'], prefix='Title')
df = pd.concat([df, title_dummies], axis=1)

# One-Hot Encoding pour Embarked (port d'embarquement)
embarked_dummies = pd.get_dummies(df['Embarked'], prefix='Embarked')
df = pd.concat([df, embarked_dummies], axis=1)

## 3. Normalisation/Standardisation des variables numériques
# Initialisation du scaler
scaler = StandardScaler()

# Standardisation de l'âge et du tarif
df[['Age_scaled', 'Fare_scaled']] = scaler.fit_transform(df[['Age', 'Fare']])

# Affichage des résultats
print("\nDataFrame après transformations:")
print(df.head())

# Vérification des nouvelles colonnes
print("\nColonnes créées:")
print(df[['FamilySize', 'Title', 'Sex_encoded', 'Age_scaled', 'Fare_scaled']].head())
print("\nColonnes one-hot encodées:")
print(title_dummies.head())
# Out:
# DataFrame après transformations:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Title_Master Title_Miss  Title_Mr  \
# 0      0         A/5 21171   7.2500  ...        False      False      True
# 1      0          PC 17599  71.2833  ...        False      False     False
# ...

# %%
# Exercice 4

Q1 = train_updated['Fare'].quantile(0.25)
Q3 = train_updated['Fare'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
train_updated = train_updated[(train_updated['Fare'] >= lower_bound) & (train_updated['Fare'] <= upper_bound)]

train_updated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
print(train_updated.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          499
# Embarked         0
# dtype: int64

# %%
Q1 = train_updated['Age'].quantile(0.25)
Q3 = train_updated['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
train_updated = train_updated[(train_updated['Age'] >= lower_bound) & (train_updated['Age'] <= upper_bound)]

train_updated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
print(train_updated.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          499
# Embarked         0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# Appliquer MinMaxScaler à toutes les colonnes numériques
train_updated[train_updated.select_dtypes(include=['number']).columns] = \
    MinMaxScaler().fit_transform(train_updated.select_dtypes(include=['number']))

# %% [markdown]
# Sélection des colonnes : On utilise select_dtypes pour ne prendre que les colonnes numériques
#
# Conversion : fit_transform retourne un array numpy, qu'on doit reconvertir en DataFrame
#
# Noms de colonnes : Important de les conserver pour la lisibilité

# %%
train_updated
# Out:
#      PassengerId  Survived  Pclass  \
# 0       0.000000       0.0     1.0
# 2       0.002247       1.0     1.0
# 3       0.003371       1.0     0.0
# 4       0.004494       0.0     1.0
# 6       0.006742       0.0     0.0
# ..           ...       ...     ...
# 885     0.994382       0.0     1.0
# 886     0.995506       0.0     0.5
# 887     0.996629       1.0     0.0
# 889     0.998876       1.0     0.0
# 890     1.000000       0.0     1.0
#
#                                              Name     Sex       Age  SibSp  \
# 0                         Braund, Mr. Owen Harris    male  0.350438    0.2
# 2                          Heikkinen, Miss. Laina  female  0.415395    0.0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.561546    0.2
# 4                        Allen, Mr. William Henry    male  0.561546    0.0
# 6                         McCarthy, Mr. Timothy J    male  0.870088    0.0
# ..                                            ...     ...       ...    ...
# ...

# %%
## 1. Charger les données
df = pd.read_csv('train.csv')

## 2. Évaluer l'échelle et distribution (version corrigée)
def assess_data(df, show_plots=True):
    # Statistiques descriptives
    print("Statistiques descriptives:")
    print(df.describe())
    
    if show_plots:
        # Une seule figure pour tous les histogrammes
        plt.figure(figsize=(12, 10))
        df.select_dtypes(include=['number']).hist()
        plt.tight_layout()
        plt.show()
    
    # Analyse détaillée
    print("\nAnalyse détaillée par colonne:")
    num_cols = df.select_dtypes(include=['number']).columns
    for col in num_cols:
        print(f"\n{col}:")
        print(f"Plage: {df[col].min()} à {df[col].max()}")
        print(f"Moyenne: {df[col].mean():.2f} ± {df[col].std():.2f}")
        print(f"Skewness: {df[col].skew():.2f}")

# Premier appel avec visualisation
assess_data(df)

## 3. Prétraitement des données
wide_range_cols = ['Age', 'Fare']
bounded_cols = ['SibSp', 'Parch']
df_processed = df.copy()

## 4. Standardisation
scaler_standard = StandardScaler()
df_processed[wide_range_cols] = scaler_standard.fit_transform(df_processed[wide_range_cols])

## 5. Normalisation
scaler_minmax = MinMaxScaler()
df_processed[bounded_cols] = scaler_minmax.fit_transform(df_processed[bounded_cols])

## 6. Vérification (sans réafficher les plots)
print("\nAprès transformation:")
assess_data(df_processed, show_plots=False)  # Désactive les plots pour la vérification

print("\nDataFrame transformé:")
print(df_processed.head())
# Out:
# Statistiques descriptives:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# Analyse détaillée par colonne:
#
# PassengerId:
# ...

# %%
# One-Hot Encoding pour variables nominales
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# Label Encoding pour variables ordinales
le = LabelEncoder()
df['Pclass'] = le.fit_transform(df['Pclass'])

# Suppression des colonnes non utiles
df.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# Vérification
print(df.head())
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  \
# 0            1         0       2  22.0      1      0   7.2500      True
# 1            2         1       0  38.0      1      0  71.2833     False
# 2            3         1       2  26.0      0      0   7.9250     False
# 3            4         1       0  35.0      1      0  53.1000     False
# 4            5         0       2  35.0      0      0   8.0500      True
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True

# %%
# 1. Handle missing values
train_updated['Age'] = train_updated['Age'].fillna(train_updated['Age'].median())

# 2. Create bins
bins = [0, 12, 18, 30, 50, 100]
labels = ['Child', 'Teen', 'Young Adult', 'Adult', 'Senior']
train_updated['AgeGroup'] = pd.cut(train_updated['Age'], bins=bins, labels=labels, right=False)

# 3. One-hot encoding
age_dummies = pd.get_dummies(train_updated['AgeGroup'], prefix='Age')
train_updated = pd.concat([train_updated, age_dummies], axis=1)

# 4. Visualization
plt.figure(figsize=(10, 6))
train_updated['AgeGroup'].value_counts().sort_index().plot(kind='bar')
plt.title('Passenger Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# Show final columns
print("\nFinal columns with age groups:")
print(train_updated.filter(regex='Age|PassengerId').head())
# Out:
# Final columns with age groups:
#    PassengerId       Age AgeGroup  Age_Child  Age_Teen  Age_Young Adult  \
# 0     0.000000  0.350438    Child       True     False            False
# 2     0.002247  0.415395    Child       True     False            False
# 3     0.003371  0.561546    Child       True     False            False
# 4     0.004494  0.561546    Child       True     False            False
# 6     0.006742  0.870088    Child       True     False            False
#
#    Age_Adult  Age_Senior
# 0      False       False
# 2      False       False
# 3      False       False
# 4      False       False
# 6      False       False
