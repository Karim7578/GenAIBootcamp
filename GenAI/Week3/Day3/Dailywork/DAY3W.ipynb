# %%
import pandas as pd

df = pd.read_csv('weatherHistory.csv')
print(df.head())
df.describe()
df.info()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
pip install scikit-learn
# Out:
# ...
#                                               0.0/10.7 MB ? eta -:--:--
#                                               0.2/10.7 MB 5.3 MB/s eta 0:00:02
#                                               0.3/10.7 MB 3.2 MB/s eta 0:00:04
#      -                                        0.3/10.7 MB 2.8 MB/s eta 0:00:04
#      -                                        0.4/10.7 MB 2.3 MB/s eta 0:00:05
#      -                                        0.4/10.7 MB 2.2 MB/s eta 0:00:05
#      -                                        0.4/10.7 MB 2.2 MB/s eta 0:00:05
#      -                                        0.4/10.7 MB 1.4 MB/s eta 0:00:08
#      -                                        0.5/10.7 MB 1.4 MB/s eta 0:00:08
#      --                                       0.5/10.7 MB 1.4 MB/s eta 0:00:08
#      --                                       0.6/10.7 MB 1.4 MB/s eta 0:00:08
#      --                                       0.7/10.7 MB 1.5 MB/s eta 0:00:07
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df['Temperature_normalized'] = scaler.fit_transform(df['Temperature (C) '])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Temperature_normalized'] = scaler.fit_transform(df[['Temperature (C)']])

print(df['Temperature_normalized'])
# Out:
# 0        0.506975
# 1        0.505085
# 2        0.505445
# 3        0.487805
# 4        0.495365
#            ...
# 96448    0.774998
# 96449    0.751778
# 96450    0.710557
# 96451    0.702187
# 96452    0.684637
# Name: Temperature_normalized, Length: 96453, dtype: float64

# %%
# from sklearn.decomposition import PCA

# #This line creates an instance of the PCA class with the parameter n_components set to 2. It specifies that we want to reduce the dimensionality of the data to 2 principal components. In other words, the data will be projected into a 2D space.
# pca = PCA(n_components=2)
# reduced_df= pca.fit_transform(df)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])  # Only numeric columns
pca = PCA(n_components=2)
reduced_df = pca.fit_transform(numeric_df)

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Apply PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(numeric_df)  # This is a NumPy array

# Convert to DataFrame for easier analysis
reduced_df = pd.DataFrame(reduced_data, columns=['PC1', 'PC2'])

# Now you can use all DataFrame methods
print("First 5 rows:")
print(reduced_df.head())

print("\nSummary statistics:")
print(reduced_df.describe())

print("\nDataFrame info:")
print(reduced_df.info())
# Out:
# First 5 rows:
#          PC1        PC2
# 0   7.572204  64.164118
# 1   7.529264  72.179517
# 2  11.592634  17.266136
# 3   7.632113  82.201400
# 4   8.418255  72.215924
#
# Summary statistics:
#                 PC1           PC2
# count  9.645300e+04  9.645300e+04
# mean  -1.009324e-13 -1.538879e-14
# std    1.170132e+02  1.073406e+02
# min   -1.012562e+03 -2.551471e+02
# 25%    5.205409e+00 -7.385757e+01
# 50%    1.248370e+01 -6.962951e+00
# 75%    2.091751e+01  1.026918e+02
# max    5.561342e+01  1.735913e+02
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PC1     96453 non-null  float64
#  1   PC2     96453 non-null  float64
# dtypes: float64(2)
# memory usage: 1.5 MB
# None

# %%
# # Convert to DataFrame for easier analysis
# reduced_df = pd.DataFrame(reduced_data, columns=['PC1', 'PC2'])

# # Now you can use all DataFrame methods
# print("First 5 rows:")
# print(reduced_df.head())

# print("\nSummary statistics:")
# print(reduced_df.describe())

# print("\nDataFrame info:")
# print(reduced_df.info())

# %%
# groupby('Humidity')['Temperature (C)

# df_grouped = df.groupby(pd.Grouper('Humidity')['Temperature (C)].sum()

# %%
df_grouped = df.groupby('Humidity')['Temperature (C)'].mean()

print(df_grouped.head())

print(df_grouped.describe())

print(df_grouped.info())
# Out:
# Humidity
# 0.00   -298.333333
# 0.12     13.888889
# 0.13     39.905556
# 0.14    130.550000
# 0.15    255.144444
# Name: Temperature (C), dtype: float64
# count       90.000000
# mean     12788.251481
# std       7510.911640
# min       -298.333333
# 25%       8025.459722
# 50%      14767.538889
# 75%      16373.941667
# max      49652.788889
# Name: Temperature (C), dtype: float64
# <class 'pandas.core.series.Series'>
# Index: 90 entries, 0.0 to 1.0
# Series name: Temperature (C)
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     float64
# dtypes: float64(1)
# memory usage: 1.4 KB
# None

# %%
df_grouped = df.groupby('Humidity')['Temperature (C)'].mean()

# df_grouped = df.groupby (pd.Grouper ('Humidity').sum()

print(df_grouped.head())

print(df_grouped.describe())

print(df_grouped.info())
# Out:
# Humidity
# 0.00   -13.560606
# 0.12    13.888889
# 0.13    39.905556
# 0.14    32.637500
# 0.15    25.514444
# Name: Temperature (C), dtype: float64
# count    90.000000
# mean     17.215613
# std       9.077470
# min     -13.560606
# 25%      10.159932
# 50%      16.858000
# 75%      24.618813
# max      39.905556
# Name: Temperature (C), dtype: float64
# <class 'pandas.core.series.Series'>
# Index: 90 entries, 0.0 to 1.0
# Series name: Temperature (C)
# Non-Null Count  Dtype
# --------------  -----
# 90 non-null     float64
# dtypes: float64(1)
# memory usage: 1.4 KB
# None
