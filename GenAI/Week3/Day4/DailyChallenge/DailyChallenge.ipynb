# %% [markdown]
# Load and Inspect Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
happiness_data = pd.read_csv('2019.csv')

# Display basic info
happiness_data.info
happiness_data.describe
# Out:
# <bound method NDFrame.describe of      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
happiness_data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# 2 Data Preprocessing:
#
# Address missing values and adjust data types as necessary.

# %%
# missing values
print(happiness_data.isnull().sum())

# Define numerical columns (adjust according to actual CSV)
numerical_columns = ['Score', 'GDP per capita', 'Social support',
                   'Healthy life expectancy', 'Freedom to make life choices',
                   'Generosity', 'Perceptions of corruption']

# Filter to only existing columns
numerical_columns = [col for col in numerical_columns if col in happiness_data.columns]
print("\nNumerical columns used:", numerical_columns)

# Handle missing values by median imputation
for column in numerical_columns:
    median = happiness_data[column].median()
    happiness_data[column].fillna(median, inplace=True)
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64
#
# Numerical columns used: ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_19048\3965265744.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# 3 Social Support and Happiness:
#
#     Employ a Matplotlib scatter plot to investigate the relationship between ‘Social support’ and ‘Score’.

# %%
# Define numerical columns (adjust according to actual CSV)
numerical_columns = ['Score', 'GDP per capita', 'Social support',
                   'Healthy life expectancy', 'Freedom to make life choices',
                   'Generosity', 'Perceptions of corruption']

# Filter to only existing columns
numerical_columns = [col for col in numerical_columns if col in happiness_data.columns]
print("\nNumerical columns used:", numerical_columns)

# Handle missing values by median imputation
for column in numerical_columns:
    median = happiness_data[column].median()
    happiness_data[column].fillna(median, inplace=True)

# Verify missing values after treatment
print("\n=== Missing Values After Treatment ===")
print(happiness_data.isnull().sum())
# Out:
# Numerical columns used: ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
#
# === Missing Values After Treatment ===
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_19048\1258429945.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# 4 Regional Comparisons of GDP and Health:
#
#     Create a Matplotlib subplot that compares ‘GDP per Capita’ and ‘Healthy Life Expectancy’ across different regions.
#     Use a bar plot for ‘GDP per Capita’ and a line plot for ‘Healthy Life Expectancy’ on the same axes to observe how economic strength relates to health outcomes in different regions.

# %%
# Objective: Investigate relationship between Social Support and Happiness Score
if 'Social support' in happiness_data.columns and 'Score' in happiness_data.columns:
    plt.figure(figsize=(10, 6))
    plt.scatter(happiness_data['Social support'], happiness_data['Score'], 
               alpha=0.6, color='purple')
    plt.title('Relationship Between Social Support and Happiness Score (2019)')
    plt.xlabel('Social Support (0-1)')
    plt.ylabel('Happiness Score (0-10)')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()
else:
    print("\nCannot create plot: Missing required columns")

# Objective: Compare GDP and Health metrics across regions
if 'Region' in happiness_data.columns:
    regional_means = happiness_data.groupby('Region')[['GDP per capita', 
                                                     'Healthy life expectancy']].mean()
    
    # GDP Comparison (Bar Plot)
    plt.figure(figsize=(12, 6))
    regional_means['GDP per capita'].plot(kind='bar', 
                                        color='skyblue', 
                                        edgecolor='black')
    plt.title('Average GDP per Capita by Region (2019)')
    plt.xlabel('Region')
    plt.ylabel('GDP per Capita')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
    
    # Health Comparison (Bar Plot)
    plt.figure(figsize=(12, 6))
    regional_means['Healthy life expectancy'].plot(kind='bar', 
                                                 color='lightgreen', 
                                                 edgecolor='black')
    plt.title('Healthy Life Expectancy by Region (2019)')
    plt.xlabel('Region')
    plt.ylabel('Years')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
else:
    print("\nCannot create regional plots: 'Region' column missing")

# ----- 4.3 Correlation Matrix -----
plt.figure(figsize=(10, 8))
correlations = happiness_data[numerical_columns].corr()
sns.heatmap(correlations, 
           annot=True, 
           cmap='coolwarm', 
           center=0, 
           fmt=".2f",
           linewidths=0.5, 
           linecolor='white')
plt.title('Correlations Between Happiness Factors', pad=20)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Cannot create regional plots: 'Region' column missing
