# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o', markerfacecolor='blue', markersize=12)
plt.show()

# %%
categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
plt.bar(categories, values, color=['red', 'green', 'blue', 'purple'], edgecolor='black', hatch='/')
plt.title('Customized Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
import numpy as np

data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=30, edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
brands = ['Apple', 'Samsung', 'Huawei', 'Xiaomi', 'Others']
market_share = [40, 30, 15, 10, 5]

plt.pie(market_share, labels=brands, autopct='%1.1f%%')
plt.title('Smartphone Market Share 2023')
plt.show()

# %%
explode = (0.1, 0, 0, 0, 0)
plt.pie(market_share, labels=brands, autopct='%1.1f%%', explode=explode)
plt.show()

# %%
explode = (0.1, 0, 0, 0, 0)
plt.pie(market_share, labels=brands, autopct='%1.1f%%', explode=explode)
plt.show()

# %%
import numpy as np

data = np.random.randn(100)
plt.boxplot(data)
plt.title('Basic Box Plot')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# 1. Line Plot Exercise:
#
# Create a line plot for the function y = x^2 for x ranging from 0 to 10. Add appropriate labels and a title.
#
# 2. Bar Chart Exercise:
#
# Visualize the sales of five products (e.g., Product A, Product B, etc.) in a bar chart. Customize the chart with different colors and patterns.
#
# 3. Histogram Exercise:
#
# Generate a dataset of 500 random numbers following a normal distribution. Plot the histogram and experiment with different bin sizes and colors.
#
# 4. Pie Chart Exercise:
#
# Create a pie chart showing the percentage distribution of time spent on different daily activities (e.g., work, sleep, leisure, exercise, etc.). Use custom colors and add a shadow effect.

# %%
#Line Plot

x = range(0, 30)
y = [i * 2 for i in x]  # Multiply each element in x by 2

plt.plot(x, y)
plt.show()

# %%
x = range(0, 11)
y = [i**2 for i in x]
plt.plot(x, y, color='green', linestyle='--', marker='o')
plt.title("Line Plot: y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %% [markdown]
# The code you provided has a small issue. The problem is that you're trying to multiply a range object by 2 (y = x*2), which isn't the correct way to create a sequence where each element from x is multiplied by 2.

# %% [markdown]
# 2. Bar Chart Exercise:
#
# Visualize the sales of five products (e.g., Product A, Product B, etc.) in a bar chart. Customize the chart with different colors and patterns.

# %%
categories = ['Product A', 'Product B', 'OProduct C', 'Product D', 'Product E' ]
values = [20, 35, 30, 15,10]

plt.bar(categories, values, color=['red', 'green', 'blue', 'purple'])
plt.title('sales')
plt.show()

# %%
products = ["Product A", "Product B", "Product C", "Product D", "Product E"]
sales = [200, 400, 300, 450, 500]
plt.bar(products, sales, color=['red', 'blue', 'green', 'orange', 'purple'])
plt.title("Bar Chart: Product Sales")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# 3. Histogram Exercise:
#
# Generate a dataset of 500 random numbers following a normal distribution. Plot the histogram and experiment with different bin sizes and colors.

# %%
data = np.random.normal(0, 1, 500)
plt.hist(data, bins=15, color='cyan', edgecolor='black')
plt.title("Histogram: Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 4. Pie Chart Exercise:
#
# Create a pie chart showing the percentage distribution of time spent on different daily activities (e.g., work, sleep, leisure, exercise, etc.). Use custom colors and add a shadow effect.

# %%
activities = ['Work', 'Sleep', 'Exercise', 'Leisure']
time_spent = [8, 7, 2, 7]
explode = (0.1, 0, 0, 0)
plt.pie(time_spent, labels=activities, autopct='%1.1f%%', explode=explode, shadow=True)
plt.title("Pie Chart: Daily Activities")
plt.show()

# %%
pip install seaborn
# Out:
# ...
#                                               0.0/294.9 kB ? eta -:--:--
#      -------------------------------------- 294.9/294.9 kB 9.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
# Load sample data
data = sns.load_dataset('tips')
sns.histplot(data['total_bill'], bins=20, color='skyblue')
plt.title('Histogram of Total Bill')
plt.show()

# %%
sns.kdeplot(data['total_bill'], shade=True, color='purple')
plt.title('KDE of Total Bill')
plt.show()
# Out:
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_17304\1284017743.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['total_bill'], shade=True, color='purple')

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='scatter', color='green')
plt.show()

# %%
titanic = sns.load_dataset('titanic')
sns.barplot(x='class', y='survived', data=titanic, palette='Blues')
plt.title('Survival Rate by Class')
plt.show()
# Out:
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_17304\1143395905.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='class', y='survived', data=titanic, palette='Blues')

# %%
sns.boxplot(x='class', y='age', data=titanic, palette='Set3')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_17304\1651098642.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=titanic, palette='Set3')

# %%
sns.violinplot(x='class', y='age', data=titanic, palette='muted')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# C:\Users\Zbook\AppData\Local\Temp\ipykernel_17304\1279526175.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='class', y='age', data=titanic, palette='muted')

# %%
sns.lmplot(x='total_bill', y='tip', data=data, aspect=1.5, height=5)
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='reg', color='orange')
plt.show()

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species', palette='Dark2')
plt.show()

# %%
# correlation_matrix = iris.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix Heatmap')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 correlation_matrix = iris.corr()
#       2 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#       3 plt.title('Correlation Matrix Heatmap')
#
# File c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# ...

# %%
correlation_matrix = iris.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
data = sns.load_dataset('tips')
g = sns.FacetGrid(data, col='time', row='smoker', margin_titles=True)
g.map(sns.scatterplot, 'total_bill', 'tip', color='red')
plt.show()

# %%
iris = sns.load_dataset('iris')
g = sns.PairGrid(iris, hue='species')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap='Blues')
g.map_diag(sns.histplot, kde=True, color='teal')
g.add_legend()
plt.show()
# Out:
# c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
# ...

# %%
sns.set_context('talk')
sns.set_style('whitegrid')
sns.histplot(data['total_bill'], color='darkblue', bins=15)
plt.title('Advanced Aesthetic Customization')
plt.show()

# %%
1. Create a histogram of customer spending from the tips dataset. Customize the bins and color.

2. Use pairplot on the iris dataset with different markers for species.

3. Visualize correlations in the iris dataset using a heatmap.

4. Build a FacetGrid using the titanic dataset to compare survival rates by age across class and gender.

# %% [markdown]
# 1. Create a histogram of customer spending from the tips dataset. Customize the bins and color.

# %%
data = sns.load_dataset('tips')
sns.set_context('talk')
sns.set_style('darkgrid')
sns.histplot(data['total_bill'], bins=20, color='lightgreen')
plt.title('Histogram of Total Bill')
plt.show()

# %% [markdown]
# 2. Use pairplot on the iris dataset with different markers for species.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species', palette='Dark2')
plt.show()

# %% [markdown]
# 3. Visualize correlations in the iris dataset using a heatmap.

# %%
correlation_matrix = iris.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# 4. Build a FacetGrid using the titanic dataset to compare survival rates by age across class and gender.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('titanic')
g = sns.FacetGrid(data, col='age', row='survived', margin_titles=True)
g.map(sns.scatterplot, 'class', 'gender', color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       4 data = sns.load_dataset('titanic')
#       5 g = sns.FacetGrid(data, col='age', row='survived', margin_titles=True)
# ----> 6 g.map(sns.scatterplot, 'class', 'gender', color='red')
#       7 plt.show()
#
# File c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:748, in FacetGrid.map(self, func, *args, **kwargs)
#     745     kwargs["label"] = utils.to_utf8(self.hue_names[hue_k])
#     747 # Get the actual data we are going to plot with
# --> 748 plot_data = data_ijk[list(args)]
#     749 if self._dropna:
#     750     plot_data = plot_data.dropna()
#
# File c:\Users\Zbook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
Correlation Matrix
correlation = iris.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Heatmap: Correlation Matrix")
plt.show()
# Out:
#   Cell In[6], line 1
#     Correlation Matrix
#                 ^
# SyntaxError: invalid syntax

# %%
Histogram
data = sns.load_dataset('tips')
sns.histplot(data['total_bill'], bins=15, kde=True, color='blue')
plt.title("Histogram: Total Bill")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Histogram
#       2 data = sns.load_dataset('tips')
#       3 sns.histplot(data['total_bill'], bins=15, kde=True, color='blue')
#
# NameError: name 'Histogram' is not defined

# %%
Pairplots
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species')
plt.title("Pair Plot: Iris Dataset")
plt.show()

# %%
Facet Grid
titanic = sns.load_dataset('titanic')
g = sns.FacetGrid(titanic, col="sex", row="class", margin_titles=True)
g.map(sns.histplot, "age", kde=True)
plt.show()
