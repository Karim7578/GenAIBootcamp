# %% [markdown]
# Exercice 1

# %% [markdown]
# Il s’agit de l’analyse de données fournis idéalement par une source fiable. Cette analyse permet d’analyser un marché, de définir les besoins consommateurs, de faire des prévisions et d’évaluer la viabilité d’un produit ou d’un marché par exemple.
#
# L’analyse de données est un outil de prise de décision et d’analyse de marché.
# C’est utilisé en politique, par exemple les sondages. Cela permet à un candidat de connaître sa position lors d’une élection.
# C’est utilisé dans le domaine de l’industrie, pour analyser les futurs besoins des consommateurs et ses habitudes de consommation, l’évolution de certain marché cible et le cycle de vie des produits.
# C’est aussi utilisé dans la finance afin de prédire l’évolution du marché et des actions.
#
# Voici des cas concrets d'utilisation  des données pour développer des nouveaux concepts.
#
# Computer vision
# De nombreux industriels utilisent la vision par ordinateur pour détecter des problèmes de qualité ou de sécurité (comme des accidents du travail). Mais cette forme d’IA, pour être efficace, doit bien souvent être en temps réel, souligne Jennifer Cooke.
# Les responsables de la chaîne d’approvisionnement ont en effet besoin d’informations quasi instantanément sur les problèmes. Le edge – et l’IA embarquée – permet ce temps réel grâce à sa rapidité de traitement des données.
# 2. Robots et véhicules autonomes
# La robotique nécessite également un traitement presque temps réel des informations et des données, ce qui fait de l’informatique en périphérie un outil particulièrement adapté à ces cas d’usage.
# Les robots et les véhicules autonomes doivent en effet réagir à leur environnement. La latence doit être aussi limitée que possible. L’analyse des données des robots et des véhicules doit donc se faire à proximité des appareils, voire dans les appareils, rappelle Shubho Ghosh.
# En outre, le edge permet à ces appareils de continuer à fonctionner même si l’accès à l’internet est soudainement interrompu, ce qui est évidemment ce que souhaitent les industriels, ajoute Joseph Fitzgerald.
# 3. Maintenance prédictive
# « De nombreux fabricants d’équipements industriels intègrent désormais des capteurs dans leurs machines [pour la maintenance prédictive] et mettent en place des plates-formes logicielles pour agréger les données qui proviennent non seulement d’un site particulier, mais aussi de tous les sites dans le monde entier », constate Jennifer Cooke.
# L’analyse de ces données est effectuée dans le cloud (ou à distance), mais l’informatique en périphérie peut également traiter une petite partie de ces données, souligne-t-elle. « Et il est souvent moins cher de le faire en edge ».
# « Moins cher » parce que le système traite moins de données. Par exemple, un utilisateur peut regarder la moyenne des relevés d’un appareil sur une période et utiliser les capacités du edge pour traiter ces données au lieu d’envoyer tous les relevés de tous ses capteurs dans un cloud.
# 4. Processus flexibles et réactifs
# Parce qu’il est rapide, le edge computing peut rendre les processus plus souples.
# L’informatique en périphérie permet ainsi de modifier rapidement les processus pour répondre à des situations changeantes, avance Jospeh Fitzgerald. Par exemple, pour identifier un problème avec un dispositif d’étalonnage et procéder à des ajustements immédiats.
# Ces ajustements, plus rapides, permettent par ailleurs d’économiser de l’argent et d’améliorer l’efficacité.
# 5. Sécurité renforcée
# La particularité que possède le edge computing à fonctionner sans accès à internet est indispensable pour certains secteurs industriels qui ont besoin d’un très haut niveau de sécurité.
# C’est par exemple le cas du domaine aérospatial et celui de la défense qui ont recours à des appareils sans connexion vers l’extérieur, en raison de la nature sensible des tâches qu’ils doivent assurer, illustre Jospeh Fitzgerald. Grâce à l’informatique en périphérie, ces appareils peuvent cependant continuer à traiter en local en toute sécurité les données dont ils ont besoin.

# %% [markdown]
# Exercice 2

# %% [markdown]
#  How Much Sleep Do Americans Really Get?
#
#     Load the dataset into Jupyter or Google Colab.
#     Display the first few rows.
#     Provide a brief dataset description.

# %%
import pandas as pd

df = pd.read_csv('Time Americans Spend Sleeping.csv')
print(df.head())
df.describe()
df.info()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
# ...

# %%
df = pd.read_csv('Mental health Depression disorder Data.csv')
print(df.head())
df.describe()
df.info()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
df = pd.read_csv(r'C:\Users\Zbook\Desktop\GenAI\Fichier de travail\clean_dataset.csv')
print(df.head())
df.describe()
df.info()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# Exercice 3
#
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64  	quantitative
#  1   Year                      945 non-null    int64  	quantitative
#  2   Period                    945 non-null    object 	qualitative
#  3   Avg hrs per day sleeping  945 non-null    float64	quantitative
#  4   Standard Error            945 non-null    float64	quantitative
#  5   Type of Days              945 non-null    object 	qualitative
#  6   Age Group                 945 non-null    object 	qualitative
#  7   Activity                  945 non-null    object 	qualitative
#  8   Sex                       945 non-null    object 	qualitative
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB
#
# #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64  	quantitative
#  1   Entity                     108553 non-null  object 	qualitative
#  2   Code                       103141 non-null  object 	qualitative
#  3   Year                       108553 non-null  object 	qualitative
#  4   Schizophrenia (%)          25875 non-null   object 	qualitative
#  5   Bipolar disorder (%)       19406 non-null   object 	qualitative
#  6   Eating disorders (%)       100236 non-null  object 	qualitative
#  7   Anxiety disorders (%)      6468 non-null    float64	quantitative
#  8   Drug use disorders (%)     6468 non-null    float64	quantitative
#  9   Depression (%)             6468 non-null    float64	quantitative
#  10  Alcohol use disorders (%)  6468 non-null    float64	quantitative
#
#
# Data columns (total 16 columns):
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64  	quantitative
#  1   Age             690 non-null    float64	quantitative
#  2   Debt            690 non-null    float64	quantitative
#  3   Married         690 non-null    int64  	quantitative
#  4   BankCustomer    690 non-null    int64  	quantitative
#  5   Industry        690 non-null    object 	qualitative
#  6   Ethnicity       690 non-null    object 	qualitative
#  7   YearsEmployed   690 non-null    float64	quantitative
#  8   PriorDefault    690 non-null    int64  	quantitative
#  9   Employed        690 non-null    int64  	quantitative
#  10  CreditScore     690 non-null    int64  	quantitative
#  11  DriversLicense  690 non-null    int64  	quantitative
#  12  Citizen         690 non-null    object 	qualitative
#  13  ZipCode         690 non-null    int64  	quantitative
#  14  Income          690 non-null    int64  	quantitative
#  15  Approved        690 non-null    int64  	quantitative

# %% [markdown]
# Exercice 4

# %%
import pandas as pd

df = pd.read_csv('Iris.csv')
print(df.head())
df.describe()
df.info()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# ...

# %% [markdown]
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative
#
#
# #   Column         Non-Null Count  Dtype  	 	Comments
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64  	quantitative	it's an integer so it's quantitative
#  1   SepalLengthCm  150 non-null    float64	quantitative	it's a float so it's quantitative
#  2   SepalWidthCm   150 non-null    float64	quantitative	it's a float so it's quantitative
#  3   PetalLengthCm  150 non-null    float64	quantitative	it's a float so it's quantitative
#  4   PetalWidthCm   150 non-null    float64	quantitative	it's a float so it's quantitative
#  5   Species        150 non-null    object 	qualitative	it's an object so it's qualitative

# %% [markdown]
# Exercice 5

# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.read_csv('Iris.csv')

# Chargement des données
df = pd.read_csv('Iris.csv')

# Statistiques
print("\nStatistiques pour SepalLengthCm:")
print(f"Moyenne: {df['SepalLengthCm'].mean():.2f} cm")
print(f"Médiane: {df['SepalLengthCm'].median()} cm")
print(f"Mode: {df['SepalLengthCm'].mode()[0]} cm")  # [0] car mode() retourne une Series

# Visualisation
plt.figure(figsize=(8,4))
plt.hist(df['SepalLengthCm'], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribution de la longueur des sépales')
plt.xlabel('Longueur (cm)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# Statistiques pour SepalLengthCm:
# Moyenne: 5.84 cm
# Médiane: 5.8 cm
# Mode: 5.0 cm

# %%
import matplotlib.pyplot as plt

plt.plot(df['Id'], df['SepalLengthCm'])

plt.show()

# %%
# # Importation des bibliothèques nécessaires
# import pandas as pd
# import matplotlib.pyplot as plt

# # Chargement du fichier (remplacez 'sleep_data.csv' par votre fichier)
# df = pd.read_csv('Time Americans Spend Sleeping.csv')

# # Afficher les 5 premières lignes pour voir à quoi ressemblent les données
# print("Voici les premières lignes du tableau :")
# print(sleep_data.head())

# %%
# # Calcul de la moyenne de sommeil par groupe d'âge
# sleep_by_age = sleep_df.groupby('Age Group')['Time Americans Spend Sleeping.csv'].mean()

# print("\nMoyenne de sommeil par âge :")
# print(sleep_by_age)

# # Diagramme en barres
# sleep_by_age.plot(kind='bar', color='skyblue')
# plt.title("Heures de sommeil moyennes par âge")
# plt.xlabel("Groupe d'âge")
# plt.ylabel("Heures de sommeil")
# plt.show()

# %% [markdown]
# Exercice 6

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('Time Americans Spend Sleeping.csv')

print(df.head())

print(df.info())

print(df.describe())

plt.figure(figsize=(10,5))

quant_col_name = 'Avg hrs per day sleeping'

if quant_col_name in df.columns:
    quant_col = df[quant_col_name]

   
    mean_val = quant_col.mean()
    median_val = quant_col.median()
    mode_val = quant_col.mode()[0]  

    print(f"Mean: {mean_val:.2f}")
    print(f"Median: {median_val:.2f}")
    print(f"Mode: {mode_val:.2f}\n")

    # Histogramme
    plt.subplot(1, 2, 1)
    df[quant_col_name].hist(bins=20, color='skyblue')
    plt.title(f"Distribution de {quant_col_name}")
    plt.xlabel(quant_col_name)
    plt.ylabel("Fréquence")
    plt.show()
else:
    print(f"Column '{quant_col_name}' not found in the DataFrame.")
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
# ...

# %% [markdown]
# On pourra analyser la durée du sommeil en fonction du sexe dans un graphique "Sex"/"Avg hrs per day sleeping"

# %% [markdown]
# On pourra analyser la durée du sommeil en fonction du sexe dans un graphique "Sex"/"Avg hrs per day sleeping"

# %% [markdown]
# On pourra analyser la durée du sommeil en fonction du sexe dans un graphique "Type of Days"/"Avg hrs per day sleeping"
